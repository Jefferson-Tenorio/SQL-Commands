# %% [markdown]
# # Laboratório de Dados - Setup Inicial
#
# Bem-vindo ao seu ambiente de estudos!
# A conexão com o banco de dados **PostgreSQL** já foi feita automaticamente pelo script de inicialização.
#
# Vamos testar se tudo está funcionando.

# %%
# %%sql
# SELECT version(), current_user;
# Out:
#  * postgresql://postgres:***@db:5432/lab_dados
# 1 rows affected.
# [('PostgreSQL 15.17 on x86_64-pc-linux-musl, compiled by gcc (Alpine 15.2.0) 15.2.0, 64-bit', 'postgres')]

# %%
# %%sql
# SELECT table_name
# FROM information_schema.tables
# WHERE table_schema = 'public';
# Out:
#  * postgresql://postgres:***@db:5432/lab_dados
# 7 rows affected.
# [('marketing_channels',),
#  ('customers',),
#  ('categories',),
#  ('products',),
#  ('sellers',),
#  ('orders',),
#  ('order_items',)]

# %%
# Testando a integração SQL -> Pandas
import pandas as pd

# Executa query e guarda na variável 'result'
result = %sql SELECT * FROM information_schema.tables WHERE table_schema = 'public';

# Converte para DataFrame
df = result.DataFrame()

# Mostra as primeiras linhas
df.head()
# Out:
#  * postgresql://postgres:***@db:5432/lab_dados
# 7 rows affected.
#   table_catalog table_schema          table_name  table_type  \
# 0     lab_dados       public  marketing_channels  BASE TABLE
# 1     lab_dados       public           customers  BASE TABLE
# 2     lab_dados       public          categories  BASE TABLE
# 3     lab_dados       public            products  BASE TABLE
# 4     lab_dados       public             sellers  BASE TABLE
#
#   self_referencing_column_name reference_generation user_defined_type_catalog  \
# 0                         None                 None                      None
# 1                         None                 None                      None
# 2                         None                 None                      None
# 3                         None                 None                      None
# 4                         None                 None                      None
#
# ...
